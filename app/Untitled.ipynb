# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.ticker as mticker  

file_location = "C:\\python3-64\\projects\\analyze_excell\\app\\files\\Sakhar.xlsx"
data = pd.read_excel(file_location)


#print(data)

#дисперсия

# подготовка данных data.keys()[1]
# df = pd.read_excel(file_location)
# x = df.loc[:, [data.keys()[1]]]
# df['mpg_z'] = (x - x.mean())/x.std()
# df['colors'] = ['red' if x < 0 else 'green' for x in df['mpg_z']]
# df.sort_values('mpg_z', inplace=True)
# df.reset_index(inplace=True)

# plt.figure(figsize=(6,5), dpi= 80)
# plt.hlines(y=df.index, xmin=0, xmax=df.mpg_z, color=df.colors, alpha=0.4, linewidth=5)

# plt.gca().set(ylabel='Уровень сахара', xlabel='$Дисперсия$')
# plt.yticks(df[data.keys()[0]], df[data.keys()[1]], fontsize=12)
# plt.title('Величина дисперсии', fontdict={'size':20})
# plt.grid(linestyle='--', alpha=0.5)
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%d день'))

#гистограмма

# fig = plt.figure()
# plt.grid(True)
# plt.title('Гистограмма')
# plt.hist(data[data.keys()[1]])
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%d раз'))
# plt.gca().xaxis.set_major_formatter(mticker.FormatStrFormatter('%.1f \n ммоль/л'))


#среднеее значение

fig = plt.figure()
plt.boxplot([data[data.keys()[1]]])
plt.grid(True)
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%0.1f \n ммоль/л'))


#простой график

# fig = plt.figure()
# graph1 = plt.plot(data[data.keys()[0]], data[data.keys()[1]])
# grid1 = plt.grid(True)   # линии вспомогательной сетки
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.1f ммоль/литр'))
# plt.gca().xaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f день'))
plt.show()
